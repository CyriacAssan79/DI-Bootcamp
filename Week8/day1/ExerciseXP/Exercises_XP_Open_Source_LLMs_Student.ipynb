# %% [markdown]
# # Exercises XP: Open-Source LLM Strategy (Student)
# Use this guided notebook and fill each TODO. Run it in Colab if you prefer; GPU not required unless you try optional model runs.

# %% [markdown]
# ## What you'll learn
# - Identify degrees of openness in LLMs and what each enables.
# - Understand and compare open-source licenses.
# - Assess strengths/trade-offs of open LLMs for specific constraints (CPU, math, multilingual).
# - Evaluate which models fit given hardware and licensing needs.
# - Use open tools/leaderboards to guide model selection.
# - Plan deployment trade-offs (local vs. cloud).

# %% [markdown]
# ## What you will create
# - Comparative LLM openness analysis (table + paragraph + healthcare prompt answer).
# - Licensing compatibility checklist for SaaS products.
# - Quiz-style reflection on LLM selection.
# - Local deployment readiness checklist + upgrade notes.
# - Benchmark-based model match guide.
# - Hardware upgrade plan / cost-benefit comparison (local vs. cloud).

# %% [markdown]
# ## Exercise 1: Open Source Levels Reflection
# **Use:** Fully Open, Weights Released, Architecture Only; model components; fine-tuning/domain adaptation; healthcare compliance.
#
# **Step-by-step**
# 1) Gather definitions for the three openness levels.
# 2) Identify key characteristics (what is open; what you can/cannot do).
# 3) Compare side by side in a table (what's open vs. impact).
# 4) Write a 3?5 sentence comparative paragraph.
# 5) Answer the healthcare prompt (1?2 sentences) about retraining on clinical data.
#
# **Deliverables:** paragraph + healthcare answer.

# %%
# TODO: capture definitions and key characteristics
open_source_levels = {
    "Fully Open": {
        "definition": "A fully open model provides access to the model architecture, the training code, the pretrained weights, and usually the training methodology under an open-source license.",
        "what_is_open": ["Model architecture and source code", "Pretrained weights and training pipeline"],
        "what_you_can_do": ["Inspect, modify, fine-tune, and retrain the model", "Deploy and customize the model for specific applications"],
        "what_you_cannot_do": ["You may still need significant computing resources", "License terms must still be respected"],
    },
    "Weights Released": {
        "definition": "The pretrained model weights are publicly available, but the complete training code or dataset may not be released.",
        "what_is_open": ["Pretrained weights","Usually the model architecture"],
        "what_you_can_do": ["Fine-tune the model on your own data","Run inference and adapt the model for downstream tasks"],
        "what_you_cannot_do": ["Cannot fully reproduce the original training process","Cannot inspect or modify every component of the training pipeline"],
    },
    "Architecture Only": {
        "definition":"Only the model architecture or research paper is available, while the pretrained weights are not released.",
        "what_is_open": ["Model architecture","Research description or implementation details"],
        "what_you_can_do": ["Study and reimplement the architecture", "Train a new model from scratch if sufficient data and compute are available"],
        "what_you_cannot_do": ["Cannot use the original pretrained model","Cannot fine-tune without pretrained weights"],
    },
}
open_source_levels
# Out:
# {'Fully Open': {'definition': 'A fully open model provides access to the model architecture, the training code, the pretrained weights, and usually the training methodology under an open-source license.',
#   'what_is_open': ['Model architecture and source code',
#    'Pretrained weights and training pipeline'],
#   'what_you_can_do': ['Inspect, modify, fine-tune, and retrain the model',
#    'Deploy and customize the model for specific applications'],
#   'what_you_cannot_do': ['You may still need significant computing resources',
#    'License terms must still be respected']},
#  'Weights Released': {'definition': 'The pretrained model weights are publicly available, but the complete training code or dataset may not be released.',
#   'what_is_open': ['Pretrained weights', 'Usually the model architecture'],
#   'what_you_can_do': ['Fine-tune the model on your own data',
#    'Run inference and adapt the model for downstream tasks'],
# ...

# %%
# TODO: fill the comparison table (keep markdown formatting)
comparison_table = """| Openness level | What's open? | Impact on retraining/modifying |
| --- | --- | --- |
| Fully Open | Architecture, source code, pretrained weights, training pipeline | Full freedom to inspect, modify, fine-tune, and retrain the model. |
| Weights Released | Pretrained weights (and usually architecture) | Fine-tuning is possible, but reproducing or modifying the complete training process is limited. |
| Architecture Only | Model architecture and design | The architecture can be studied or reimplemented, but pretrained knowledge cannot be reused without training from scratch. |"""
print(comparison_table)
# Out:
# | Openness level | What's open? | Impact on retraining/modifying |
# | --- | --- | --- |
# | Fully Open | Architecture, source code, pretrained weights, training pipeline | Full freedom to inspect, modify, fine-tune, and retrain the model. |
# | Weights Released | Pretrained weights (and usually architecture) | Fine-tuning is possible, but reproducing or modifying the complete training process is limited. |
# | Architecture Only | Model architecture and design | The architecture can be studied or reimplemented, but pretrained knowledge cannot be reused without training from scratch. |

# %%
# TODO: 3?5 sentence comparative paragraph
comparative_paragraph = """Fully Open models provide access to both the model's architecture and pretrained weights, allowing complete inspection, modification, and retraining. Models with released weights allow users to fine-tune pretrained models for new tasks but usually do not provide the full training pipeline, limiting reproducibility. Architecture-only models reveal how the model is designed but do not include pretrained weights, making them useful for research but requiring expensive training from scratch. Therefore, the degree of openness directly affects how easily a model can be adapted and deployed for real-world applications."""
print(comparative_paragraph)

# %%
# TODO: 1?2 sentence healthcare prompt answer
healthcare_prompt_answer = """For a healthcare assistant that must be adapted using clinical data, the Weights Released level is the minimum requirement because fine-tuning requires access to pretrained weights. A Fully Open model is even better, since it provides complete transparency, supports deeper customization, and facilitates compliance, auditing, and domain-specific retraining."""
print(healthcare_prompt_answer)

# %% [markdown]
# ## Exercise 2: License Check for SaaS Use
# **Use:** HF model pages; permissive vs. copyleft; commercial clauses; restrictions (MAU caps, attribution, export controls).
#
# **Step-by-step**
# 1) Select two HF models (e.g., Mistral-7B-Instruct, Llama-2-7b-chat-hf) and note URLs.
# 2) Locate the License field and copy the name.
# 3) Determine if commercial use is allowed/restricted/prohibited; note conditions.
# 4) Identify extra restrictions (MAU caps, attribution, export/geography).
# 5) Build the markdown checklist with your findings.
#
# **Deliverables:** model names + URLs + completed checklist.

# %%
# TODO: record model metadata from the HF pages
license_checklist = [
    {
        "model": "mistralai/Mistral-7B-Instruct-v0.3",
        "url": "https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3",
        "license": "Apache 2.0",
        "commercial_use": "Yes",
        "restrictions": ["Must include the Apache 2.0 license and copyright notice when redistributing.", "Modifications must be documented; no trademark rights are granted."],
    },
    {
        "model": "meta-llama/Llama-2-7b-chat-hf",
        "url": "https://huggingface.co/meta-llama/Llama-2-7b-chat-hf",
        "license": "Llama 2 Community License",
        "commercial_use": "Conditional",
        "restrictions": ["Commercial use is allowed under the Llama 2 Community License.","Organizations with more than 700 million monthly active users must obtain a separate commercial license from Meta."],
    },
]
license_checklist
# Out:
# [{'model': 'mistralai/Mistral-7B-Instruct-v0.3',
#   'url': 'https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3',
#   'license': 'Apache 2.0',
#   'commercial_use': 'Yes',
#   'restrictions': ['Must include the Apache 2.0 license and copyright notice when redistributing.',
#    'Modifications must be documented; no trademark rights are granted.']},
#  {'model': 'meta-llama/Llama-2-7b-chat-hf',
#   'url': 'https://huggingface.co/meta-llama/Llama-2-7b-chat-hf',
#   'license': 'Llama 2 Community License',
#   'commercial_use': 'Conditional',
#   'restrictions': ['Commercial use is allowed under the Llama 2 Community License.',
#    'Organizations with more than 700 million monthly active users must obtain a separate commercial license from Meta.']}]

# %% [markdown]
# ### Checklist template (fill and keep in markdown)
# - [ ] **Mistral**
#   - Type of license:
#     - [ ] Apache 2.0
#   - Commercial use allowed:
#     - [ ] Yes
#   - Restrictions:
#     - [ ] Must include the Apache 2.0 license and copyright notice when redistributing.
#     - [ ] Modifications must be documented; no trademark rights are granted.
# - [ ] **Llama**
#   - Type of license:
#     - [ ] Llama 2 Community License
#   - Commercial use allowed:
#     - [ ] Conditional
#   - Restrictions:
#     - [ ] Commercial use is allowed under the Llama 2 Community License.
#     - [ ] Organizations with more than 700 million monthly active users must obtain a separate commercial license from Meta.

# %% [markdown]
# ## Exercise 3: LLM Matchmaker Challenge
# **Use:** CPU inference, low-end laptops, multilingual needs; HF filters; size <=7B; benchmarks (BoolQ, GSM8K, FLORES-200).
#
# **Step-by-step**
# 1) Analyze team needs (LegalTech CPU logic; EdTech math/logic low-end; Global NGO multilingual >=5 langs).
# 2) Apply HF filters (cpu/quantized, logic/math/multilingual tags, size <=7B).
# 3) List 3?5 candidates per team with params/arch/quantization/benchmarks.
# 4) Compare top 2 per team and pick the best model with justification.
# 5) Fill the table with your picks.
#
# **Deliverables:** filter summary + filled picks table.

# %%
# TODO: jot down search filters or URLs for each team
filters_by_team = {
    "LegalTech": [
        "Task: text-generation",
        "Hardware: CPU / GGUF / Quantized",
        "Keywords: logic, reasoning, BoolQ",
        "Model size: <= 7B parameters",
        "https://huggingface.co/models?pipeline_tag=text-generation"],
    "EdTech": [
        "Task: text-generation",
        "Hardware: CPU / GGUF / Quantized",
        "Keywords: math, GSM8K, reasoning",
        "Prefer <= 4B parameters",
        "https://huggingface.co/models?pipeline_tag=text-generation"],
    "Global NGO": [
        "Task: text-generation",
        "Keywords: multilingual",
        "Hardware: CPU compatible",
        "Model size: <= 7B parameters",
        "https://huggingface.co/models?pipeline_tag=text-generation"
    ],
}
filters_by_team
# Out:
# {'LegalTech': ['Task: text-generation',
#   'Hardware: CPU / GGUF / Quantized',
#   'Keywords: logic, reasoning, BoolQ',
#   'Model size: <= 7B parameters',
#   'https://huggingface.co/models?pipeline_tag=text-generation'],
#  'EdTech': ['Task: text-generation',
#   'Hardware: CPU / GGUF / Quantized',
#   'Keywords: math, GSM8K, reasoning',
#   'Prefer <= 4B parameters',
#   'https://huggingface.co/models?pipeline_tag=text-generation'],
#  'Global NGO': ['Task: text-generation',
#   'Keywords: multilingual',
#   'Hardware: CPU compatible',
#   'Model size: <= 7B parameters',
#   'https://huggingface.co/models?pipeline_tag=text-generation']}

# %%
# TODO: candidate lists per team (3?5 each)
candidates_by_team = {
    "LegalTech": [
        {
            "model": "mistralai/Mistral-7B-Instruct-v0.3",
            "params_b": "7B", "arch": "Mistral",
            "optimization": "GGUF, 4-bit, 8-bit",
            "benchmarks": "Strong reasoning, BoolQ, ReClor"
        },
        {
            "model": "Qwen/Qwen2.5-7B-Instruct",
            "params_b": "7B",
            "arch": "Qwen2.5",
            "optimization": "GGUF, GPTQ, AWQ",
            "benchmarks": "Excellent reasoning, MMLU, BoolQ"
        },
    ],
    "EdTech": [
        {
            "model": "microsoft/Phi-3-mini-4k-instruct",
            "params_b": "3.8B",
            "arch": "Phi-3",
            "optimization": "4-bit, GGUF",
            "benchmarks": "Excellent GSM8K and MATH scores"
        },
        {
            "model": "google/gemma-2-2b-it",
            "params_b": "2B",
            "arch": "Gemma 2",
            "optimization": "4-bit, GGUF",
            "benchmarks": "Good reasoning with very low RAM usage"
        }
    ],
    "Global NGO": [
        {
            "model": "bigscience/bloom-7b1",
            "params_b": "7.1B",
            "arch": "BLOOM",
            "optimization": "8-bit, GGUF",
            "benchmarks": "Supports 46+ languages"
        },

        {
            "model": "Qwen/Qwen2.5-7B-Instruct",
            "params_b": "7B",
            "arch": "Qwen2.5",
            "optimization": "GGUF, GPTQ",
            "benchmarks": "Supports 29+ languages"
        }
    ],
}
candidates_by_team
# Out:
# {'LegalTech': [{'model': 'mistralai/Mistral-7B-Instruct-v0.3',
#    'params_b': '7B',
#    'arch': 'Mistral',
#    'optimization': 'GGUF, 4-bit, 8-bit',
#    'benchmarks': 'Strong reasoning, BoolQ, ReClor'},
#   {'model': 'Qwen/Qwen2.5-7B-Instruct',
#    'params_b': '7B',
#    'arch': 'Qwen2.5',
#    'optimization': 'GGUF, GPTQ, AWQ',
#    'benchmarks': 'Excellent reasoning, MMLU, BoolQ'}],
#  'EdTech': [{'model': 'microsoft/Phi-3-mini-4k-instruct',
#    'params_b': '3.8B',
#    'arch': 'Phi-3',
#    'optimization': '4-bit, GGUF',
#    'benchmarks': 'Excellent GSM8K and MATH scores'},
#   {'model': 'google/gemma-2-2b-it',
#    'params_b': '2B',
#    'arch': 'Gemma 2',
#    'optimization': '4-bit, GGUF',
#    'benchmarks': 'Good reasoning with very low RAM usage'}],
#  'Global NGO': [{'model': 'bigscience/bloom-7b1',
#    'params_b': '7.1B',
#    'arch': 'BLOOM',
#    'optimization': '8-bit, GGUF',
#    'benchmarks': 'Supports 46+ languages'},
# ...

# %%
# TODO: final picks table (keep markdown formatting)
matchmaker_table = """| Team | Needs | Your Pick |
| --- | --- | --- |
| LegalTech | Fast model for logic-heavy chatbot on CPU | Qwen/Qwen2.5-7B-Instruct (excellent logical reasoning, efficient GGUF quantization for CPU inference)  |
| EdTech | Logic/math-focused LLM on low-end laptops | microsoft/Phi-3-mini-4k-instruct (strong GSM8K performance with only 3.8B parameters and low RAM requirements)  |
| Global NGO | Model that speaks 5+ languages well | bigscience/bloom-7b1 (native multilingual support across more than 40 languages with good CPU-quantized deployments) |"""
print(matchmaker_table)
# Out:
# | Team | Needs | Your Pick |
# | --- | --- | --- |
# | LegalTech | Fast model for logic-heavy chatbot on CPU | Qwen/Qwen2.5-7B-Instruct (excellent logical reasoning, efficient GGUF quantization for CPU inference)  |
# | EdTech | Logic/math-focused LLM on low-end laptops | microsoft/Phi-3-mini-4k-instruct (strong GSM8K performance with only 3.8B parameters and low RAM requirements)  |
# | Global NGO | Model that speaks 5+ languages well | bigscience/bloom-7b1 (native multilingual support across more than 40 languages with good CPU-quantized deployments) |

# %% [markdown]
# ## Exercise 4: Local Readiness Audit
# **Use:** RAM/disk/OS; llama.cpp requirements (AVX/SSE, cmake/make/gcc/clang); quantized formats (GGUF).
#
# **Step-by-step**
# 1) Gather system specs (RAM, free disk, OS type/version).
# 2) Fill the audit table and mark ?/?.
# 3) Check llama.cpp readiness (instruction sets, compilers, build tools).
# 4) Identify upgrade needs for each ?.
#
# **Deliverables:** filled table + upgrade summary.

# %%
# TODO: your measured system specs
system_specs = {
    "ram_gb": "16GB",
    "free_disk_gb": "80GB",
    "os": "Windows 11 with WSL2 (Ubuntu Linux)",
}
system_specs
# Out:
# {'ram_gb': '16GB',
#  'free_disk_gb': '80GB',
#  'os': 'Windows 11 with WSL2 (Ubuntu Linux)'}

# %%
# TODO: readiness table (keep markdown formatting)
readiness_table = """| Requirement | Your System Specs | Meets Requirement? |
| --- | --- | --- |
| RAM (>= 16 GB) | 16GB | Yes |
| Free Disk Space (>= 40 GB) | 80GB | Yes |
| OS (Linux/WSL2) | Windows 11 with WSL2 (Ubuntu) | Yes |"""
print(readiness_table)
# Out:
# | Requirement | Your System Specs | Meets Requirement? |
# | --- | --- | --- |
# | RAM (>= 16 GB) | 16GB | Yes |
# | Free Disk Space (>= 40 GB) | 80GB | Yes |
# | OS (Linux/WSL2) | Windows 11 with WSL2 (Ubuntu) | Yes |

# %%
# TODO: llama.cpp readiness notes
llama_cpp_readiness = {
    "cpu_instruction_support": "AVX2 supported (recommended for modern Intel processors)",
    "tooling": [
        "cmake",
        "gcc/g++",
        "make",
        "git"
    ],
    "other_requirements": (
        "Install llama.cpp, download a GGUF quantized model "
        "(preferably Q4_K_M or Q4_0), and ensure sufficient RAM "
        "for inference."
    ),
}
llama_cpp_readiness
# Out:
# {'cpu_instruction_support': 'AVX2 supported (recommended for modern Intel processors)',
#  'tooling': ['cmake', 'gcc/g++', 'make', 'git'],
#  'other_requirements': 'Install llama.cpp, download a GGUF quantized model (preferably Q4_K_M or Q4_0), and ensure sufficient RAM for inference.'}

# %%
# TODO: upgrade or mitigation actions
upgrade_actions = [
    "No mandatory hardware upgrade is required to run a 7B quantized GGUF model.",
    "Install the required development tools (cmake, gcc/g++, make, git) if they are not already installed.",
    "Use a 4-bit GGUF model (Q4_K_M or Q4_0) to reduce memory usage.",
    "If larger models (13B or 30B) are needed in the future, upgrade to at least 32 GB RAM.",
    "Keeping more than 40 GB of free disk space is recommended for storing multiple models."
]
upgrade_actions
# Out:
# ['No mandatory hardware upgrade is required to run a 7B quantized GGUF model.',
#  'Install the required development tools (cmake, gcc/g++, make, git) if they are not already installed.',
#  'Use a 4-bit GGUF model (Q4_K_M or Q4_0) to reduce memory usage.',
#  'If larger models (13B or 30B) are needed in the future, upgrade to at least 32 GB RAM.',
#  'Keeping more than 40 GB of free disk space is recommended for storing multiple models.']

# %% [markdown]
# ## Exercise 5: Benchmark-Based Model Explorer
# **Use:** Open LLM Leaderboard; HellaSwag and MMLU scores; license types; use-case mapping.
#
# **Step-by-step**
# 1) Pick three models from the leaderboard with different strengths (high HellaSwag, high MMLU, balanced).
# 2) Record HellaSwag, MMLU, license, and ideal use case.
# 3) Fill the comparison table.
# 4) Optional: 1?2 sentence reflection on why benchmarks matter.
# 5) Quiz-style reflection: write 3 short Q&A items about choosing models for different constraints.
#
# **Deliverables:** model list + filled table + quiz-style reflection (+ optional reflection paragraph).

# %%
# TODO: leaderboard picks
leaderboard_models = [
    {
        "model": "mistralai/Mistral-7B-Instruct-v0.3",
        "url": "https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3",
        "hellaswag": "84.82",
        "mmlu": "62.58",
        "license": "Apache 2.0",
        "ideal_use_case": "Customer support chatbot with strong reasoning"
    },
    {
        "model": "ajibawa-2023/Code-Mistral-7B",
        "url": "https://huggingface.co/ajibawa-2023/Code-Mistral-7B",
        "hellaswag": "85.29",
        "mmlu": "65.00",
        "license": "Apache 2.0",
        "ideal_use_case": "Programming assistant and code generation"
    },
    {
        "model": "Zardos/Kant-Test-0.1-Mistral-7B",
        "url": "https://huggingface.co/Zardos/Kant-Test-0.1-Mistral-7B",
        "hellaswag": "82.84",
        "mmlu": "63.38",
        "license": "Apache 2.0",
        "ideal_use_case": "General-purpose question answering and reasoning"
    },
]
leaderboard_models
# Out:
# [{'model': 'mistralai/Mistral-7B-Instruct-v0.3',
#   'url': 'https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3',
#   'hellaswag': '84.82',
#   'mmlu': '62.58',
#   'license': 'Apache 2.0',
#   'ideal_use_case': 'Customer support chatbot with strong reasoning'},
#  {'model': 'ajibawa-2023/Code-Mistral-7B',
#   'url': 'https://huggingface.co/ajibawa-2023/Code-Mistral-7B',
#   'hellaswag': '85.29',
#   'mmlu': '65.00',
#   'license': 'Apache 2.0',
#   'ideal_use_case': 'Programming assistant and code generation'},
#  {'model': 'Zardos/Kant-Test-0.1-Mistral-7B',
#   'url': 'https://huggingface.co/Zardos/Kant-Test-0.1-Mistral-7B',
#   'hellaswag': '82.84',
#   'mmlu': '63.38',
#   'license': 'Apache 2.0',
#   'ideal_use_case': 'General-purpose question answering and reasoning'}]

# %%
# TODO: comparison table (keep markdown formatting)
benchmark_table = """| Model Name | HellaSwag Score | MMLU Score | License Type | Ideal Use Case |
| --- | --- | --- | --- | --- |
| mistralai/Mistral-7B-Instruct-v0.3 | 84.82 | 62.58 | Apache 2.0 | Customer support chatbot |
| ajibawa-2023/Code-Mistral-7B | 85.29 | 65.00 | Apache 2.0 | Programming assistant and code generation |
| Zardos/Kant-Test-0.1-Mistral-7B | 82.84 | 63.38 | Apache 2.0 | General-purpose question answering |
"""
print(benchmark_table)
# Out:
# | Model Name | HellaSwag Score | MMLU Score | License Type | Ideal Use Case |
# | --- | --- | --- | --- | --- |
# | mistralai/Mistral-7B-Instruct-v0.3 | 84.82 | 62.58 | Apache 2.0 | Customer support chatbot |
# | ajibawa-2023/Code-Mistral-7B | 85.29 | 65.00 | Apache 2.0 | Programming assistant and code generation |
# | Zardos/Kant-Test-0.1-Mistral-7B | 82.84 | 63.38 | Apache 2.0 | General-purpose question answering |

# %% [markdown]
# ### Optional reflection
# 1?2 sentences on why benchmarks?not hype?should guide model choice.

# %%
# TODO: quiz-style reflection (3 short Q&A items on model selection)
quiz_reflection = [
     {
        "question": "Why is HellaSwag an important benchmark?",
        "answer": "Because it measures commonsense reasoning and logical inference."
    },
    {
        "question": "Why should you check a model's license before deployment?",
        "answer": "The license determines whether commercial use, modification, and redistribution are allowed."
    },
    {
        "question": "Should you choose a model only because it is popular?",
        "answer": "No. Model selection should primarily be guided by benchmark performance, licensing, hardware requirements, and the target application."
    },
]
quiz_reflection

# %% [markdown]
# ## Exercise 6: Cloud vs. Local Deployment Plan
# **Use:** local vs. cloud cost/latency/scalability/security/maintenance; optional Colab timing.
#
# **Step-by-step**
# 1) Draft 5 bullets pairing local vs. cloud pros/cons.
# 2) Optional: run a 7B model on Colab; note model and response time.
# 3) Summarize Colab observation if you ran it.
#
# **Deliverables:** 5 bullets; optional Colab report (model + time).

# %%
pros_and_cons = [
    "Local Deployment: Lower operational cost (no recurring cloud fees) vs. Cloud Deployment: Higher recurring costs but no upfront hardware investment.",
    "Local Deployment: Better data privacy and control vs. Cloud Deployment: Data resides on third-party servers.",
    "Local Deployment: Limited scalability (tied to local hardware) vs. Cloud Deployment: Highly scalable on-demand resources.",
    "Local Deployment: Higher latency for external access vs. Cloud Deployment: Generally lower latency for users in proximity to data centers.",
    "Local Deployment: Requires local IT expertise for setup and maintenance vs. Cloud Deployment: Managed services reduce maintenance burden."
]
pros_and_cons
# Out:
# ['Local Deployment: Lower operational cost (no recurring cloud fees) vs. Cloud Deployment: Higher recurring costs but no upfront hardware investment.',
#  'Local Deployment: Better data privacy and control vs. Cloud Deployment: Data resides on third-party servers.',
#  'Local Deployment: Limited scalability (tied to local hardware) vs. Cloud Deployment: Highly scalable on-demand resources.',
#  'Local Deployment: Higher latency for external access vs. Cloud Deployment: Generally lower latency for users in proximity to data centers.',
#  'Local Deployment: Requires local IT expertise for setup and maintenance vs. Cloud Deployment: Managed services reduce maintenance burden.']

# %%
# Optional: Colab timing note
colab_run = {
    "model_tested": "TODO",
    "response_time_seconds": "TODO",
    "notes": "TODO",
}
colab_run
