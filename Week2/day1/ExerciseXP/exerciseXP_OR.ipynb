# %% [markdown]
# ## **Exercice 1 : Analyse de données de base avec Kaggle**

# %%
import pandas as pd

# %%
df_boston = pd.read_csv('housing.csv')

# %%
df_boston.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
df_boston['RM'].describe()
# Out:
# count    489.000000
# mean       6.240288
# std        0.643650
# min        3.561000
# 25%        5.880000
# 50%        6.185000
# 75%        6.575000
# max        8.398000
# Name: RM, dtype: float64

# %% [markdown]
# On obtient une moyenne de  6.240288 pour 489 observations, l'écart type est  3.561 et la médiane est 6.185

# %% [markdown]
# ## **Exercice 2 : Analyse comparative des données de vente au détail**

# %%
df_feature = pd.read_csv('Retail/Features data set.csv')

# %%
df_feature.head(5)
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
df_feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
df_feature['IsHoliday'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# Dans le retail, le fichier feature comporte 8190 échantillons, de plus dans ce fichier, il y 12 variables qui peuvent être répartis en variables qualitative (Date, IsHoliday) et variables quantitative (Store, température, CPI, etc.).

# %%
df_feature['IsHoliday'].value_counts()
# Out:
# IsHoliday
# False    7605
# True      585
# Name: count, dtype: int64

# %%
df_feature.describe().T
# Out:
#                count         mean           std       min          25%  \
# Store         8190.0    23.000000     12.987966     1.000    12.000000
# Temperature   8190.0    59.356198     18.678607    -7.290    45.902500
# Fuel_Price    8190.0     3.405992      0.431337     2.472     3.041000
# MarkDown1     4032.0  7032.371786   9262.747448 -2781.450  1577.532500
# MarkDown2     2921.0  3384.176594   8793.583016  -265.760    68.880000
# MarkDown3     3613.0  1760.100180  11276.462208  -179.260     6.600000
# MarkDown4     3464.0  3292.935886   6792.329861     0.220   304.687500
# MarkDown5     4050.0  4132.216422  13086.690278  -185.170  1440.827500
# CPI           7605.0   172.460809     39.738346   126.064   132.364839
# Unemployment  7605.0     7.826821      1.877259     3.684     6.634000
#
#                       50%          75%            max
# Store           23.000000    34.000000      45.000000
# Temperature     60.710000    73.880000     101.950000
# ...

# %% [markdown]
# La moyenne de vente par magasin est de 23

# %%
df_ecommerce = pd.read_csv('ecommerce.csv')

# %%
df_ecommerce.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %%
df_ecommerce['Title'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                                      NaN
# 1                                                      NaN
# 2                                  Some major design flaws
# 3                                         My favorite buy!
# 4                                         Flattering shirt
#                                ...
# 23481                       Great dress for many occasions
# 23482                           Wish it was made of cotton
# 23483                                Cute, but see through
# 23484    Very cute dress, perfect for summer parties an...
# 23485                      Please make more like this one!
# Name: Title, Length: 23486, dtype: object>

# %% [markdown]
# ## **Exerice 3**

# %%
df = pd.read_csv('data.csv',encoding="latin1")

# %%
df.head()

# %%
df.info()

# %% [markdown]
# Pour les données structuerer, on peut avoir la date, Quantity, CustomerID, Country
#
# Pour compléter on peut ajouer des données sémi structuré comme les logs ou ajouter des données non strutucturé répesentant les produits du magasin
#
# Ces données pourrait être utilile si, par exemple, on a un ensemple de produit et on veut pas parcourir à chaque fois un pour voir la photo du produit

# %% [markdown]
# ## **Exerice 4**

# %%
df_rating= pd.read_csv('data/rating.csv')

# %%
df_rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %% [markdown]
# Les éléments structurés, on peut avoir le timestamp, le rating, le userId et le movieID

# %% [markdown]
# Lorsqu'on prend par exemple le timestant on remarque que les donnnées pas en vrague dans le csv mais sont bien structuré en fonction du temps, on peut aussi avoir le rating

# %% [markdown]
# ## **Exerice 6**

# %%
# !pip install faker

# %%
import numpy as np
from faker import Faker
import pandas as pd
import random
import uuid

# %%
fake = Faker('fr_FR')
unique_id = uuid.uuid4()

# Generating synthetic names and ages
data = [(unique_id, fake.name(), fake.paragraph(), np.random.randint(1, 500)) for _ in range(500)]

# %%
# Converting to a DataFrame
df = pd.DataFrame(data, columns=['ID', 'Name','Paragraph', 'Price'])

# %%
df.head()
