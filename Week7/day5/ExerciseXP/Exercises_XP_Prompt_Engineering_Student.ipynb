# %% [markdown]
# # Exercises XP: Prompt Engineering
# Use this guided notebook and fill each TODO before running cells.

# %% [markdown]
# ## What you'll learn
# - Analyze and improve vague prompts for clarity and usefulness.
# - Apply role, constraint, tone, and structure techniques.
# - Build multi-part prompts that control output format and reduce hallucinations.

# %% [markdown]
# ## What you'll build
# - A polished marketing prompt.
# - A structured educational prompt (summary + quiz) for Google Slides.
# - Context-rich prompts for finance updates, support chatbots, and marketing blurbs.

# %% [markdown]
# ## Exercise 1: Rewrite and Optimize a Vague Prompt
# **Scenario**: Manager asks for a LinkedIn post about FlowNest with the vague prompt `"Write something about productivity tips."`

# %% [markdown]
# ### Tasks
# - Identify 3 critical issues with the prompt.
# - Rewrite it using: role prompting, clear instructions, and format/tone/length constraints.
# - Add a final line to make it reusable for future social posts.

# %%
# TODO: list three critical issues with the vague prompt
critical_issues = [
    'La publication doit utiliser une voix professionnelle',
    'La publication cible principalement les professionnels en télétravail et les entrepreneurs qui souhaitent mieux se concentrer pendant leur journée de travail',
    'La publication doit encourager l’interaction (commentaires/partages) et inciter les lecteurs à découvrir l’application FlowNest via un appel à l’action',
]
critical_issues

# %%
rewritten_prompt = """Joue le rôle d'un spécialiste marketing pour FlowNest (une startup), rédige une publication LinkedIn concise (maximum 280 mots) sur des astuces de productivité. La publication doit cibler les professionnels en télétravail et les entrepreneurs qui cherchent à améliorer leur concentration. Le ton doit être professionnel et engageant, encourager les commentaires et les partages, et inclure un appel à l'action clair invitant les lecteurs à découvrir l'application FlowNest"""
rewritten_prompt
# Out:
# "Joue le rôle d'un spécialiste marketing pour FlowNest (une startup), rédige une publication LinkedIn concise (maximum 280 mots) sur des astuces de productivité. La publication doit cibler les professionnels en télétravail et les entrepreneurs qui cherchent à améliorer leur concentration. Le ton doit être professionnel et engageant, encourager les commentaires et les partages, et inclure un appel à l'action clair invitant les lecteurs à découvrir l'application FlowNest"

# %% [markdown]
# ## Exercise 2: Multi-Part Prompt for Quiz Generation
# **Scenario**: Create an educational prompt for 7th graders about volcanic eruptions.

# %% [markdown]
# ### Tasks
# - Ask for: 2-bullet summary + 3 MCQs (1 correct, 2 distractors).
# - Require friendly tone, simple vocab (11?13 y/o), and Google Slides-ready output.
# - Explain 3 ways your prompt improves on: `Make a quiz for kids about this article.`

# %%
# TODO: write the full multi-part prompt
quiz_prompt = """Supposons que tu es un professeur de sciences d'une classe de 5e. Ce cours doit comporter 2 chapitres et être adapté à des élèves qui ont entre 11 et 13 ans. Chaque chapitre aura 3 questions de fin pour évaluer la compréhension des élèves où dans chaque question il y aura une reponse exacte et une reponse fause. Tu exportes le tout dans un format Google Slides."""
quiz_prompt
# Out:
# "Supposons que tu es un professeur de sciences d'une classe de 5e. Ce cours doit comporter 2 chapitres et être adapté à des élèves qui ont entre 11 et 13 ans. Chaque chapitre aura 3 questions de fin pour évaluer la compréhension des élèves où dans chaque question il y aura une reponse exacte et une reponse fause. Tu exportes le tout dans un format Google Slides."

# %%
# TODO: explain three improvements over the vague prompt
improvements = [
    'L\'age des élèves n\'est pas spécifié',
    'Le nombre de chapitre que doit comporter le cours n\'est pas définie',
    'Le niveau des élèves n\'est pas spécifié',
]
improvements
# Out:
# ["L'age des élèves n'est pas spécifié",
#  "Le nombre de chapitre que doit comporter le cours n'est pas définie",
#  "Le niveau des élèves n'est pas spécifié"]

# %% [markdown]
# ## Exercise 3: Add Context, Get Better Results
# **Scenario**: Intern's vague request: `Summarize this report.`

# %% [markdown]
# ### Tasks
# 1) Fill the table by marking missing context and what to add.
# 2) Rewrite the prompt including at least 4 context types (role, audience, purpose, input, format/style, constraints).

# %%
# TODO: fill the context table
context_table = {
    'Role': {'missing': True, 'add': 'Demander à l\'IA d\'agir comme un analyste financier ou un assistant en finance.'},
    'Audience': {'missing': True, 'add': 'Préciser que le résumé est destiné aux participants de la réunion mensuelle (direction, managers, équipe financière).'},
    'Purpose': {'missing': True, 'add': 'Expliquer que le résumé doit servir à une présentation orale de 3 minutes mettant en évidence les principaux résultats financiers.'},
    'Input Source': {'missing': True, 'add': 'Fournir le rapport financier à résumer (ou son texte, son PDF, etc.).'},
    'Format/Style': {'missing': True, 'add': 'Demander un résumé clair, structuré, avec des puces ou de courts paragraphes, en mettant en avant les chiffres clés (revenus, dépenses, bénéfices, évolution, etc.).'},
    'Constraints': {'missing': True, 'add': 'Limiter le résumé à 3 minutes de présentation, inclure uniquement les informations essentielles et utiliser un langage simple et professionnel.'},
}
context_table
# Out:
# {'Role': {'missing': True,
#   'add': "Demander à l'IA d'agir comme un analyste financier ou un assistant en finance."},
#  'Audience': {'missing': True,
#   'add': 'Préciser que le résumé est destiné aux participants de la réunion mensuelle (direction, managers, équipe financière).'},
#  'Purpose': {'missing': True,
#   'add': 'Expliquer que le résumé doit servir à une présentation orale de 3 minutes mettant en évidence les principaux résultats financiers.'},
#  'Input Source': {'missing': True,
#   'add': 'Fournir le rapport financier à résumer (ou son texte, son PDF, etc.).'},
#  'Format/Style': {'missing': True,
#   'add': 'Demander un résumé clair, structuré, avec des puces ou de courts paragraphes, en mettant en avant les chiffres clés (revenus, dépenses, bénéfices, évolution, etc.).'},
#  'Constraints': {'missing': True,
# ...

# %%
# TODO: rewrite the intern's prompt with richer context
finance_prompt = """Joue le role d'analyste financier ou un assistant en finance. Je veux que tu me résume ce rapport.
Il est destiné à la direction, au managers et à l'équipe financière. Ce résumé doit servir de présentation orale de 3
minutes mettant en évidence les principaux résultats financiers. Les rapports envoyé sont en pdf et en csv, tu pourras te
servir de ça. Fait un résumé clair, structuré, avec des puces ou de courts paragraphes, mettant en avant les chiffres
clés (revenus, dépenses, bénéfices, évolution). N'oublie que c'est une de présentation de à 3 minutes, inclut
uniquement les informations essentielles et utilise un langage simple et professionnel. """
finance_prompt
# Out:
# "Joue le role d'analyste financier ou un assistant en finance. Je veux que tu me résume ce rapport. \nIl est destiné à la direction, au managers et à l'équipe financière. Ce résumé doit servir de présentation orale de 3\nminutes mettant en évidence les principaux résultats financiers. Les rapports envoyé sont en pdf et en csv, tu pourras te \nservir de ça. Fait un résumé clair, structuré, avec des puces ou de courts paragraphes, mettant en avant les chiffres \nclés (revenus, dépenses, bénéfices, évolution). N'oublie que c'est une de présentation de à 3 minutes, inclut \nuniquement les informations essentielles et utilise un langage simple et professionnel. "

# %% [markdown]
# ## Exercise 4: Match Prompt to Purpose
# Pick a style (Exploratory, Structured, Conversational, Functional) to build a customer-support chatbot prompt.

# %% [markdown]
# ### Tasks
# - Write the full prompt in the chosen style.
# - Identify 2 features that prove it matches the style.
# - Justify why this style fits better than the others.

# %%
# TODO: choose a style and write the prompt
chosen_style = '''
Tu es un agent de support client amical et professionnel pour une entreprise de commerce électronique.
Réponds aux questions des clients de manière claire, polie et empathique.
Salue le client, réponds à sa demande avec des explications simples et termine en proposant une aide supplémentaire si nécessaire.
'''
prompt_template = '[WRITE YOUR PROMPT HERE]'
key_style_features = ['Ton chaleureux, naturel et empathique','Réponses claires avec une interaction semblable à une conversation humaine']
justification = '''
Le style conversationnel est le plus adapté à un chatbot de support client, car il crée une expérience agréable, met le client à l'aise et
favorise une communication naturelle tout en apportant une assistance efficace.
'''

# %% [markdown]
# ## Exercise 5: Prompt Refinement Challenge ? Control Style, Structure, and Length
# **Scenario**: Write a prompt for PulseOne Mini smartwatch email blurb.

# %% [markdown]
# ### Tasks
# 1) Enforce: friendly tone, bullet points, max 50 words, mention battery life, fitness tracking, Bluetooth.
# 2) After running, evaluate adherence and revise with stronger constraints if needed.

# %%
# TODO: initial prompt with strict constraints
pulseone_prompt_v1 = '''
Rédige une description marketing de la montre connectée PulseOne Mini.
Utilise un ton amical.
Présente le texte sous forme de liste à puces.
Le texte ne doit pas dépasser 50 mots.
Mentionne obligatoirement :
- l'autonomie de la batterie,
- le suivi de la condition physique,
- la compatibilité Bluetooth.
'''

# %%
# TODO: self-evaluate after running the prompt (did it meet constraints?)
eval_v1 = {
    'word_count_ok': True,
    'features_covered': True,
    'tone_ok': True,
    'notes': 'La réponse respecte la limite de 50 mots, utilise des puces, mentionne les trois caractéristiques demandées et adopte un ton amical.',
}

# %%
# TODO: revised prompt if constraints were missed
pulseone_prompt_v2 = '''
Rédige une description de PulseOne Mini.
Respecte STRICTEMENT les consignes suivantes :
- Ne dépasse pas 50 mots.
- Écris exactement 3 puces.
- Chaque puce présente une seule caractéristique.
- Mentionne obligatoirement l'autonomie de la batterie, le suivi de la condition physique et la compatibilité Bluetooth.
- Utilise un ton amical et engageant.
- N'ajoute aucune autre information.
'''

# %% [markdown]
# ## Exercise 6: Hallucination Spotting and Mitigation
# **Scenario**: Model added an unsupported claim in a climate/marine article summary.

# %% [markdown]
# ### Tasks
# 1) Prompt the model to avoid hallucinations using only provided text.
# 2) Rewrite with verification language.
# 3) List 2 mitigation strategies.
# 4) Name 2 domains where hallucinations are risky and why.

# %%
# TODO: baseline anti-hallucination prompt
no_hallucination_prompt = '''
Résume uniquement le texte fourni.
N'utilise aucune connaissance externe et n'ajoute aucune information qui ne figure pas explicitement dans l'article.
Si une information n'est pas présente dans le texte, ne la mentionne pas.
'''

# %%
# TODO: verification-focused rewrite
verification_prompt = '''
Résume uniquement les informations explicitement mentionnées dans l'article fourni.
N'incluez que les affirmations présentes dans le texte.
En cas de doute ou si une information est absente, indiquez : "L'information n'est pas disponible dans l'article."
Ne faites aucune supposition ni extrapolation.
'''

# %%
# TODO: list mitigation strategies and risky domains
mitigation_strategies = ["Limiter la réponse aux informations explicitement présentes dans le texte fourni.",
    "Demander au modèle d'indiquer lorsqu'une information n'est pas disponible au lieu de la deviner."]
risky_domains = {
    'domain_1': {'name': 'Soins de santé', 'why': 'Une information erronée peut conduire à un mauvais diagnostic ou à un traitement inadapté, mettant en danger la santé des patients.'},
    'domain_2': {'name': 'Droit', 'why': 'Des informations juridiques inexactes peuvent entraîner de mauvaises décisions, des litiges ou le non-respect des lois.'},
}
